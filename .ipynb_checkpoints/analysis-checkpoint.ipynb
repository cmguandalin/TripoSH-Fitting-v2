# %%
import numpy as np
from getdist import plots, MCSamples
import corner
import matplotlib.pyplot as pl
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
pl.rc('text', usetex=False)
pl.rc('font', family='DejaVu Sans')
pl.rc('font', size='14')
colours = ['#348ABD', '#A60628', '#7A68A6', '#467821', '#D55E00', '#CC79A7', '#56B4E9', '#009E73', '#F0E442', '#0072B2']
pl.style.use('bmh')
pl.rcParams.update({'axes.facecolor': 'white',
                    'axes.edgecolor': 'black'})

# %%
chain = np.load('/Users/austerlitz/Desktop/TripoSH-Fitting-v2/results/QSO/p0p2b0b2_PNG_test.npy',allow_pickle=True).item()a

# %%
chain['priors']
# Out:
# {'b1': {'type': 'Uni', 'lim': [0, 4]},
#  'b2': {'type': 'Uni', 'lim': [-15, 15]},
#  'bG2': {'type': 'Uni', 'lim': [-15, 15]},
#  'ch': {'type': 'Uni', 'lim': [-1000, 1000]},
#  'c1': {'type': 'Uni', 'lim': [-1000, 1000]},
#  'c2': {'type': 'Uni', 'lim': [-1000, 1000]},
#  'Bshot': {'type': 'Uni', 'lim': [-10, 10]},
#  'fnlequi': {'type': 'Uni', 'lim': [-5000, 5000]},
#  "fnlortho'": {'type': 'Uni', 'lim': [-5000, 5000]}}

# %%
chain = np.load('/Users/austerlitz/Desktop/TripoSH-Fitting-v2/results/QSO/p0p2b0b2_PNG_test.npy',allow_pickle=True).item()
names = [
  'b1',
  'b2',
  'bG2',
  'ch',
  'c1',
  'c2',
  'Bshot',
  'fnleq',
  'fnlort']

labels = [
 r'b_1',
 r'b_2',
 r'b_{G_2}',
 r'c_h',
 r'c_1',
 r'c_2',
 r'B_{\rm shot}',
 r'f_{\rm NL}^{\rm eq}',
 r'f_{\rm NL}^{\rm orth}']

# %%
chain.keys()
# Out:
# dict_keys(['priors', 'samples', 'weights', 'logl', 'logp'])

# %%
g = plots.get_subplot_plotter()

samples1 = MCSamples(samples=chain['samples'], weights=chain['weights'], names=names, labels=labels)

g.settings.legend_fontsize = 22
g.settings.axes_fontsize = 16
g.settings.axes_labelsize = 20

g.triangle_plot([samples1], filled=True, 
                contour_colors=['tomato'],
                   contour_lws = [3], contour_ls=['-'])
# Out:
# Removed no burn in
